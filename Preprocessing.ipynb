# %% [markdown]
# ## Retrieving and Cleaning the Dataset
# After doing some Googling I found that my dataset was located

# %%
import pandas as pd

pd.options.display.max_rows = 20
HIST_DF = pd.read_csv("hist.csv")

# Display table
HIST_DF
# Out:
#           id                                                url  \
# 0         54            https://mail.google.com/mail/u/0/#inbox
# 1        348  https://www.facebook.com/profile.php?id=100004...
# 2        551       https://www.messenger.com/t/1002100799843065
# 3        704                   https://github.com/Meeshbhoombah
# 4       1110     https://www.makeschool.com/users/auth/facebook
# 5       1347             https://www.messenger.com/t/dhruv.mand
# 6       1373         https://www.messenger.com/t/steven.abreu.3
# 7       1758                             http://www.google.com/
# 8       1934    https://www.messenger.com/t/nikhilesh.kashyap.1
# 9       6486                      https://www.messenger.com/new
# ...      ...                                                ...
# 18857  79314  https://random.kakaopor.hu/how-to-repair-an-sq...
# 18858  79315  https://random.kakaopor.hu/how-to-repair-an-sq...
# 18859  79316  https://www.google.com/search?q=convert+sqlite...
# ...

# %% [markdown]
# With one line we can see the top five most and least visited sites.

# %%
HIST_DF.sort_values(['visit_count'], ascending=False)
# Out:
#           id                                                url  \
# 284    43014                         https://www.messenger.com/
# 15361  75818  https://docs.google.com/spreadsheets/d/1x7RCob...
# 808    57840  https://docs.google.com/spreadsheets/d/1KF-7CF...
# 936    60927  https://docs.google.com/spreadsheets/d/1PUffTZ...
# 1        348  https://www.facebook.com/profile.php?id=100004...
# ...      ...                                                ...
# 758    56797  https://www.publicsafety.gc.ca/cnt/rsrcs/pblct...
# 130    37523  http://trydesignlab.com/blog/bauhaus-school-fi...
# 757    56787  https://www.foottraffik.co/key-performance-ind...
# 921    60727  https://www.mrporter.com/journal/the-interview...
# 129    37519  https://99designs.com/blog/creative-inspiratio...
#
#                                                    title  visit_count  \
# 284                                            Messenger          659
# ...
